# %% [markdown]
# Example use of `sensor_data_analysis`

# %%
from read_sql_server import sensor_data_analysis

# %%
sensor_data_analysis.phone_number_list()
# Out:
#                 phone
# 0         01223386203
# 1         01223386301
# 2         01220119423
# 3         01220100461
# 4         01220107807
# ..                ...
# 175       01220025928
# 176       01220025922
# 177  00158D00022594BF
# 178       01223136964
# 179       01220039260
#
# [180 rows x 1 columns]

# %% [markdown]
# # All data

# %%
test = sensor_data_analysis(8)

# %%
test.plotContent(['contentsCurrAct','contentsPrevAct'], 'weekly')

# %%
test.plotRoom()

# %%
test = sensor_data_analysis(73)
test.plotContent([i for i in test.target_df.columns if 'contents' in i], 'daily')
# test.plotContent(['contentsCurrAct','contentsPrevAct'], 'weekly')

# %% [markdown]
# # Individual data

# %%
test = sensor_data_analysis(8, phone_number='01223386203')

# %%
test.plotContent(['contentsCurrAct','contentsPrevAct'], 'weekly')

# %%
test = sensor_data_analysis(73, phone_number='01223386203')
test.plotContent([i for i in test.target_df.columns if 'contents' in i], 'daily')
# test.plotContent(['contentsCurrAct','contentsPrevAct'], 'weekly')
